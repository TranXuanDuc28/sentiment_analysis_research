# %% [markdown]
# # 🚀 Research Sentiment Analysis - Full 6 Scenarios Pipeline

# %% [markdown]
# ### 1. Setup & Install

# %%
from google.colab import drive
import os
drive.mount('/content/drive')

DRIVE_PATH = '/content/drive/MyDrive/sentiment_analysis_research'
if not os.path.exists(DRIVE_PATH):
    os.makedirs(DRIVE_PATH)

# %cd $DRIVE_PATH

ZIP_PATH = '/content/project.zip'
if os.path.exists(ZIP_PATH):
    # !unzip -o -q {ZIP_PATH} -d .
    print("✅ Giải nén thành công!")

if os.path.exists('backend'):
    # %cd backend

# !pip install -q pyyaml scikit-learn transformers datasets accelerate pandas

# %% [markdown]
# ### 2. Scenario 1 & 2: Baseline & Cross-domain

# %%
# !python main.py --s 1
# !python main.py --s 2

# %% [markdown]
# ### 3. Scenario 3 & 5: Multi-domain & Cross-lingual

# %%
# !python main.py --s 3
# !python main.py --s 5

# %% [markdown]
# ### 4. Scenario 4: DANN Adaptation (Twitter)

# %%
# !python main.py --s 4

# %% [markdown]
# ### 5. Scenario 6: Multilingual Training

# %%
# !python main.py --s 6
